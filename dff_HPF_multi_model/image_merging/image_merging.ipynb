# %%
from image_merger import create_tight_image_chain

image_paths = [
    "Unet-resnet34-imagenet_Multi-Domain_DFF_Analysis_TP.png",
    "Unet-resnet34-no_weight_Multi-Domain_DFF_Analysis_TP.png",
    "Unet-resnet34-sobelmag_gabor_Multi-Domain_DFF_Analysis_TP.png",
    "Unet-resnet34-sobelmaglap_Multi-Domain_DFF_Analysis_TP.png",
    "Unet-resnet34-sobelxy_Multi-Domain_DFF_Analysis_TP.png"
]
titles = [
    "Imagenet",
    "No Weight",
    "Sobel Magnitude + Gabor",
    "Sobel Magnitude + Laplacian",
    "Sobel X/Y"
]
output_name = "Multi_Domain_DFF_Analysis_TP.png"

create_tight_image_chain(image_paths, titles, output_name)

# %%
image_paths = [
    "Unet-resnet34-imagenet_Multi-Domain_DFF_Analysis_FP.png",
    "Unet-resnet34-no_weight_Multi-Domain_DFF_Analysis_FP.png",
    "Unet-resnet34-sobelmag_gabor_Multi-Domain_DFF_Analysis_FP.png",
    "Unet-resnet34-sobelmaglap_Multi-Domain_DFF_Analysis_FP.png",
    "Unet-resnet34-sobelxy_Multi-Domain_DFF_Analysis_FP.png"
]
titles = [
    "Imagenet",
    "No Weight",
    "Sobel Magnitude + Gabor",
    "Sobel Magnitude + Laplacian",
    "Sobel X/Y"
]
output_name = "Multi_Domain_DFF_Analysis_FP.png"

create_tight_image_chain(image_paths, titles, output_name)
